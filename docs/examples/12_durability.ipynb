# %% [markdown]
# # 12 · 내구성과 피복두께 — KDS 14 20 40, KDS 14 20 50
#
# KDS 14 20 40 이 수치로 규정하는 것은 **표 4.1-3 의 최소 설계기준압축강도**
# 뿐이다.
#
# - 물-결합재비·결합재·공기량·염화물량 → **KCS 14 20 10(1.10)** (4.1.4(3))
# - 피복두께 → 노출범주 EC·ES 는 **KDS 14 20 50(4.3)** 이상 (4.1.4(2))

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

# 한글 글꼴이 없는 환경에서도 그림이 깨지지 않도록 축 라벨은 ASCII 로 둔다
plt.rcParams["axes.unicode_minus"] = False
plt.rcParams["figure.dpi"] = 96

# %%
from concreteproperties_kds.detailing import MINIMUM_COVER, minimum_cover
from concreteproperties_kds.durability import (
    check_durability,
    governing_requirements,
    print_exposure_table,
)

print_exposure_table()
# Out:
# ======================================================================================
# 노출등급과 최소 설계기준압축강도 (KDS 14 20 40 표 4.1-1, 표 4.1-3)
# ======================================================================================
#    등급     범주   fck,min      피복규정  환경
# --------------------------------------------------------------------------------------
#    E0     일반        21         -  콘크리트 내부에 철근이 없거나 유해한 환경에 노출되지 않음
#   EC1    탄산화        21  14 20 50  건조하거나 항상 수중
#   EC2    탄산화        24  14 20 50  습윤하고 드물게 건조
#   EC3    탄산화        27  14 20 50  보통 습도
#   EC4    탄산화        30  14 20 50  주기적인 건습 반복
#   ES1    염화물        30  14 20 50  해양 대기 중 (직접 접촉 없음)
#   ES2    염화물        30  14 20 50  영구히 수중
#   ES3    염화물        35  14 20 50  간만대 또는 물보라 지역
#   ES4    염화물        35  14 20 50  제설염 등 염화물에 노출
#   EF1   동결융해        24         -  수분과 접촉하나 제빙화학제 없음, 동결융해 반복
#   EF2   동결융해        27         -  제빙화학제 노출, 동결융해 반복
#   EF3   동결융해        30         -  수분과 자주 접촉, 동결융해 반복
#   EF4   동결융해        30         -  해수 또는 제빙화학제에 노출, 동결융해 반복
#   EA1    황산염        27         -  약한 황산염 침해 (토양 SO4 2000~3000 ppm)
#   EA2    황산염        30         -  보통 황산염 침해
#   EA3    황산염        30         -  심한 황산염 침해
# --------------------------------------------------------------------------------------
# 물-결합재비·결합재·공기량·염화물량은 KCS 14 20 10(1.10) 에 따른다.

# %% [markdown]
# ## 복합 노출
#
# 해안 지역 옥외 교각은 탄산화 · 염화물 · 동결융해가 동시에 걸린다.

# %%
exposure = ["EC4", "ES1", "EF2"]
fck_min = governing_requirements(exposure_classes=exposure)

print(f"적용 노출등급 : {', '.join(exposure)}")
print(f"지배 최소 설계기준압축강도 = {fck_min:.1f} MPa")
# Out:
# 적용 노출등급 : EC4, ES1, EF2
# 지배 최소 설계기준압축강도 = 30.0 MPa

# %%
fck_design = 35.0
cover_min = minimum_cover(
    condition="흙에접하거나옥외노출", bar="D22", fck=fck_design
)
cover_design = 50.0

for cls in exposure:
    check_durability(
        exposure_class=cls, fck=fck_design,
        cover=cover_design, cover_min=cover_min,
        water_binder_ratio=0.40,
    ).print_results()
    print()
# Out:
# ========================================================================
# 내구성 검토 (KDS 14 20 40)
# ========================================================================
# 노출등급  EC4 (탄산화)
#           주기적인 건습 반복
# ------------------------------------------------------------------------
# 설계기준압축강도  fck =     35.0 MPa (표 4.1-3 요구 30.0 이상)  만족
# 피복두께          cc  =     50.0 mm (KDS 14 20 50 요구 50.0 이상)  만족
# 물-결합재비       W/B =    0.400   (KCS 14 20 10(1.10) 에서 확인할 것)
# ------------------------------------------------------------------------
# 종합                                                만족
#
# ========================================================================
# 내구성 검토 (KDS 14 20 40)
# ========================================================================
# 노출등급  ES1 (염화물)
#           해양 대기 중 (직접 접촉 없음)
# ------------------------------------------------------------------------
# 설계기준압축강도  fck =     35.0 MPa (표 4.1-3 요구 30.0 이상)  만족
# 피복두께          cc  =     50.0 mm (KDS 14 20 50 요구 50.0 이상)  만족
# 물-결합재비       W/B =    0.400   (KCS 14 20 10(1.10) 에서 확인할 것)
# ------------------------------------------------------------------------
# 종합                                                만족
#
# ========================================================================
# 내구성 검토 (KDS 14 20 40)
# ========================================================================
# 노출등급  EF2 (동결융해)
#           제빙화학제 노출, 동결융해 반복
# ------------------------------------------------------------------------
# 설계기준압축강도  fck =     35.0 MPa (표 4.1-3 요구 27.0 이상)  만족
# 피복두께               노출범주 EC·ES 가 아니므로 규정 없음
# 물-결합재비       W/B =    0.400   (KCS 14 20 10(1.10) 에서 확인할 것)
# ------------------------------------------------------------------------
# 종합                                                만족

# %% [markdown]
# ## 최소 피복두께 (KDS 14 20 50 4.3.1)
#
# 프리스트레스하지 않는 부재의 현장치기콘크리트 기준이다.
# $f_{ck} \ge 40$ MPa 저감(10 mm)은 **옥내 보·기둥에만** 적용된다.

# %%
cases = [
    ("수중", None),
    ("흙에영구히묻힘", None),
    ("흙에접하거나옥외노출", "D22"),
    ("흙에접하거나옥외노출", "D13"),
    ("옥내_슬래브벽체장선", "D38"),
    ("옥내_슬래브벽체장선", "D25"),
    ("옥내_보기둥", None),
    ("옥내_셸절판", None),
]

print(f"{'조건':<24} {'철근':>6} {'cc':>7} {'fck>=40':>9}")
print("-" * 50)
for condition, bar in cases:
    print(
        f"{condition:<24} {bar or '-':>6}"
        f" {minimum_cover(condition=condition, bar=bar):7.0f}"
        f" {minimum_cover(condition=condition, bar=bar, fck=40):9.0f}"
    )

del MINIMUM_COVER
# Out:
# 조건                           철근      cc   fck>=40
# --------------------------------------------------
# 수중                            -     100       100
# 흙에영구히묻힘                       -      75        75
# 흙에접하거나옥외노출                  D22      50        50
# 흙에접하거나옥외노출                  D13      40        40
# 옥내_슬래브벽체장선                  D38      40        40
# 옥내_슬래브벽체장선                  D25      20        20
# 옥내_보기둥                        -      40        30
# 옥내_셸절판                        -      20        20
